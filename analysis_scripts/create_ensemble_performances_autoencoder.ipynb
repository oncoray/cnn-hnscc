# %%
import os
import pandas as pd
import numpy as np

# %%
base_dir = "/home/MED/starkeseb/my_experiments/paper_evaluation_of_dl_approaches/autoencoder"

# %%
train_ids = pd.read_csv("/home/MED/starkeseb/dktk_train_ids.csv", header=None)
print(len(train_ids))

test_ids = pd.read_csv("/home/MED/starkeseb/dktk_test_ids.csv", header=None)
print(len(test_ids))
# Out:
# 206
# 85

# %%
id_col = "ID_Radiomics"
time_col = "LRCtime"
event_col = "LRC"

outcome = pd.read_csv("/home/MED/starkeseb/mbro_local/data/DKTK/outcome.csv", sep=";")
outcome = outcome[[id_col, time_col, event_col]]
outcome = outcome.set_index(id_col)
outcome
# Out:
#                 LRCtime  LRC
# ID_Radiomics
# FDG01         19.351129  1.0
# FDG03          9.889117  0.0
# FDG05         61.634497  0.0
# FDG06         62.094456  0.0
# FDG07         69.585216  0.0
# FDG09          4.172485  1.0
# FDG13          4.435318  1.0
# FDG14          7.852156  0.0
# FDG15         61.963039  0.0
# FDG16          1.478439  0.0
# FDG18          4.796715  0.0
# FDG19          3.285421  1.0
# FDG20         62.882957  0.0
# FDG22         22.176591  1.0
# FDG23         13.798768  0.0
# FDG24         14.587269  0.0
# FDG28          3.975359  1.0
# FDG29         14.455852  1.0
# FDG38         31.868583  1.0
# FDG42         62.193018  0.0
# DKTK12        15.802875  1.0
# DKTK14         8.344969  0.0
# DKTK15         4.895277  1.0
# DKTK17        61.075975  0.0
# DKTK19         9.757700  1.0
# DKTK20         1.347023  1.0
# DKTK21         7.655031  0.0
# DKTK22        61.470226  0.0
# DKTK23         1.379877  1.0
# DKTK24         7.720739  0.0
# ...                 ...  ...
# FMISO39        9.034908  1.0
# FMISO40       20.468172  0.0
# FMISO41       10.447639  1.0
# FMISO43       45.075975  0.0
# FMISO44       22.899384  0.0
# FMISO45       38.406571  0.0
# FMISO46       42.546201  0.0
# FMISO48       37.946612  0.0
# FMISO49       37.355236  0.0
# FMISO50       32.262834  0.0
# FMISO51       32.262834  0.0
# FMISO52       13.010267  0.0
# FMISO53       25.790554  0.0
# FMISO55       23.983573  0.0
# FMISO56       23.819302  0.0
# FMISO57       18.201232  0.0
# Tue007        65.248460  0.0
# Tue009        61.470226  0.0
# Tue012         8.180698  1.0
# Tue015        29.437372  0.0
# Tue016        41.133470  0.0
# Tue017        28.484600  0.0
# Tue018        25.889117  0.0
# Tue019        29.470226  0.0
# Tue020        39.293634  0.0
# Tue021        37.223819  0.0
# Tue022         5.815195  1.0
# Tue023         2.234086  0.0
# Tue024         5.749487  1.0
# Tue025         2.135524  1.0
#
# [291 rows x 2 columns]

# %% [markdown]
# # LCPHM model

# %%
exp_dir = os.path.join(base_dir, "glmnet_performance")

pred_col = "glm_prediction"

prediction_dfs = []
for rep_dir in os.listdir(exp_dir):
    if not rep_dir.startswith("rep"):
        continue
    
    rep_path = os.path.join(exp_dir, rep_dir)
    for fold_dir in os.listdir(rep_path):
        if not fold_dir.startswith("fold"):
            continue
        fold_path = os.path.join(rep_path, fold_dir)
        
        # this has an entry for each slice of a patient separately and we have to aggregate per patient
        test_pred_slice = pd.read_csv(os.path.join(fold_path, "glm_pred_test.csv"))
        # now only one entry per patient
        test_pred = test_pred_slice[["id", pred_col]].groupby("id").mean()
        test_pred["cohort"] = "test"
        
        train_pred_slice = pd.read_csv(os.path.join(fold_path, "glm_pred_train.csv"))
        train_pred = train_pred_slice[["id", pred_col]].groupby("id").mean()
        train_pred["cohort"] = "train"
        
        valid_pred_slice = pd.read_csv(os.path.join(fold_path, "glm_pred_valid.csv"))
        valid_pred = valid_pred_slice[["id", pred_col]].groupby("id").mean()
        valid_pred["cohort"] = "valid"
        
        # now combine all three
        pred = pd.concat([train_pred, valid_pred, test_pred])
        
        pred["rep"] = rep_dir.split("_")[1]
        pred["fold"] = fold_dir.split("_")[1]
        
        prediction_dfs.append(pred)

# %%
preds_all_runs = pd.concat(prediction_dfs)
preds_all_runs
# Out:
#          glm_prediction cohort rep fold
# id
# DKTK12         5.948417  train   0    0
# DKTK14         4.402805  train   0    0
# DKTK15        10.468176  train   0    0
# DKTK17         1.576831  train   0    0
# DKTK19         7.775025  train   0    0
# DKTK20        17.110536  train   0    0
# DKTK21         4.789218  train   0    0
# DKTK22         1.503324  train   0    0
# DKTK23        15.598749  train   0    0
# DKTK25         8.399048  train   0    0
# DKTK26         2.893395  train   0    0
# DKTK29        14.594887  train   0    0
# DKTK30        12.424138  train   0    0
# DKTK31        10.933075  train   0    0
# DKTK33         4.081870  train   0    0
# DKTK36         1.603016  train   0    0
# DKTK38         8.792536  train   0    0
# DKTK39         8.876683  train   0    0
# DKTK40         7.156391  train   0    0
# DKTK41         2.964431  train   0    0
# DKTK47         6.505963  train   0    0
# DKTK48         1.338247  train   0    0
# DKTK49         5.617110  train   0    0
# DKTK50         1.075330  train   0    0
# DKTK52         9.849176  train   0    0
# DKTK53         8.896846  train   0    0
# DKTK55         5.214287  train   0    0
# DKTK56         6.447292  train   0    0
# DKTK57        13.493859  train   0    0
# DKTK59         1.125712  train   0    0
# ...                 ...    ...  ..  ...
# FMISO39       -6.353602   test   2    9
# FMISO40       -3.350419   test   2    9
# FMISO41       -5.501079   test   2    9
# FMISO43       -8.776820   test   2    9
# FMISO44       -7.101761   test   2    9
# FMISO45       -7.349663   test   2    9
# FMISO46       -8.481915   test   2    9
# FMISO48      -11.891532   test   2    9
# FMISO49       -3.704560   test   2    9
# FMISO50        2.729413   test   2    9
# FMISO51       -7.555299   test   2    9
# FMISO52       -7.357339   test   2    9
# FMISO53       -5.853583   test   2    9
# FMISO55       -3.181173   test   2    9
# FMISO56       -5.476270   test   2    9
# FMISO57       -7.936710   test   2    9
# Tue007        -1.521483   test   2    9
# Tue009        -9.294793   test   2    9
# Tue012         1.924846   test   2    9
# Tue015        -4.980649   test   2    9
# Tue016         4.681304   test   2    9
# Tue017       -10.299412   test   2    9
# Tue018        -0.721736   test   2    9
# Tue019       -10.543875   test   2    9
# Tue020        15.992705   test   2    9
# Tue021        -5.240103   test   2    9
# Tue022        -5.507975   test   2    9
# Tue023        -9.379921   test   2    9
# Tue024        -2.367245   test   2    9
# Tue025        -4.661168   test   2    9
#
# [8730 rows x 4 columns]

# %%
len(np.unique(preds_all_runs.index.values))
# Out:
# 291

# %%
preds_all_runs[preds_all_runs.index == "DKTK12"]
# Out:
#         glm_prediction cohort rep fold
# id
# DKTK12        5.948417  train   0    0
# DKTK12       12.390065  train   0    1
# DKTK12        5.227293  train   0    2
# DKTK12        0.714296  train   0    3
# DKTK12       10.232490  train   0    4
# DKTK12       10.791794  train   0    5
# DKTK12        5.268115  train   0    6
# DKTK12       16.723314  valid   0    7
# DKTK12       12.037380  train   0    8
# DKTK12        5.911931  train   0    9
# DKTK12        2.944308  train   1    0
# DKTK12        8.680758  train   1    1
# DKTK12        1.829650  valid   1    2
# DKTK12        0.044451  train   1    3
# DKTK12       -0.073087  train   1    4
# DKTK12        0.213823  train   1    5
# DKTK12        6.077644  train   1    6
# DKTK12        2.676740  train   1    7
# DKTK12        6.593578  train   1    8
# DKTK12        6.162330  train   1    9
# DKTK12       10.089082  valid   2    0
# DKTK12        1.357856  train   2    1
# DKTK12        6.471187  train   2    2
# DKTK12        7.941113  train   2    3
# DKTK12        7.570560  train   2    4
# DKTK12        4.419067  train   2    5
# DKTK12       13.515009  train   2    6
# DKTK12        0.495690  train   2    7
# DKTK12        9.792734  train   2    8
# DKTK12       -5.522203  train   2    9

# %%
preds_all_runs[[pred_col]]
# Out:
#          glm_prediction
# id
# DKTK12         5.948417
# DKTK14         4.402805
# DKTK15        10.468176
# DKTK17         1.576831
# DKTK19         7.775025
# DKTK20        17.110536
# DKTK21         4.789218
# DKTK22         1.503324
# DKTK23        15.598749
# DKTK25         8.399048
# DKTK26         2.893395
# DKTK29        14.594887
# DKTK30        12.424138
# DKTK31        10.933075
# DKTK33         4.081870
# DKTK36         1.603016
# DKTK38         8.792536
# DKTK39         8.876683
# DKTK40         7.156391
# DKTK41         2.964431
# DKTK47         6.505963
# DKTK48         1.338247
# DKTK49         5.617110
# DKTK50         1.075330
# DKTK52         9.849176
# DKTK53         8.896846
# DKTK55         5.214287
# DKTK56         6.447292
# DKTK57        13.493859
# DKTK59         1.125712
# ...                 ...
# FMISO39       -6.353602
# FMISO40       -3.350419
# FMISO41       -5.501079
# FMISO43       -8.776820
# FMISO44       -7.101761
# FMISO45       -7.349663
# FMISO46       -8.481915
# FMISO48      -11.891532
# FMISO49       -3.704560
# FMISO50        2.729413
# FMISO51       -7.555299
# FMISO52       -7.357339
# FMISO53       -5.853583
# FMISO55       -3.181173
# FMISO56       -5.476270
# FMISO57       -7.936710
# Tue007        -1.521483
# Tue009        -9.294793
# Tue012         1.924846
# Tue015        -4.980649
# Tue016         4.681304
# Tue017       -10.299412
# Tue018        -0.721736
# Tue019       -10.543875
# Tue020        15.992705
# Tue021        -5.240103
# Tue022        -5.507975
# Tue023        -9.379921
# Tue024        -2.367245
# Tue025        -4.661168
#
# [8730 rows x 1 columns]

# %%
ensemble_preds = preds_all_runs[["cohort", pred_col]].groupby([preds_all_runs.index, "cohort"]).mean()
ensemble_preds
# Out:
#                 glm_prediction
# id      cohort
# DKTK12  train         5.477161
#         valid         9.547349
# DKTK14  train         4.913237
#         valid        15.317744
# DKTK15  train        12.419215
#         valid        -3.351909
# DKTK17  train         0.200958
#         valid         5.612844
# DKTK19  train         7.941060
#         valid         5.129105
# DKTK20  train        18.401298
#         valid        -1.461129
# DKTK21  train         0.666916
#         valid         3.302805
# DKTK22  train         0.814012
#         valid         5.315658
# DKTK23  train        17.085563
#         valid         7.260661
# DKTK24  train         5.203019
#         valid         4.352766
# DKTK25  train         8.606118
#         valid         4.210918
# DKTK26  train         2.827543
#         valid         2.052006
# DKTK29  train        16.543733
#         valid        10.974435
# DKTK30  train        14.301247
#         valid         7.313420
# DKTK31  train        11.728613
#         valid        12.156450
# ...                        ...
# FMISO39 test          3.132219
# FMISO40 test          8.065875
# FMISO41 test          6.847057
# FMISO43 test          1.471067
# FMISO44 test          3.084730
# FMISO45 test          2.239860
# FMISO46 test          1.994498
# FMISO48 test         -0.535987
# FMISO49 test          4.352871
# FMISO50 test         12.121060
# FMISO51 test          2.525846
# FMISO52 test          6.271104
# FMISO53 test          5.845135
# FMISO55 test          7.542984
# FMISO56 test          5.526987
# FMISO57 test         -1.737581
# Tue007  test          8.065171
# Tue009  test          6.370190
# Tue012  test          8.989290
# Tue015  test          4.405066
# Tue016  test          6.637912
# Tue017  test          3.033663
# Tue018  test          4.836692
# Tue019  test          3.213433
# Tue020  test        -23.439013
# Tue021  test          8.100634
# Tue022  test          4.333259
# Tue023  test          3.912626
# Tue024  test          6.585712
# Tue025  test          6.056575
#
# [497 rows x 1 columns]

# %%
# join the outcome 
ensemble_preds = ensemble_preds.join(outcome, on="id")

# %%
85 + 206 * 2
# Out:
# 497

# %%
# check results for test patient
np.mean(preds_all_runs.loc[preds_all_runs.index == "Tue024", pred_col].values)
# Out:
# 6.585711967569396

# %%
# check result for exploratory patient (training average)
np.mean(preds_all_runs.loc[(preds_all_runs.index == "DKTK12") & (preds_all_runs["cohort"] == "train"), [pred_col]].values)
# Out:
# 5.477160755347063

# %%
# check result for exploratory patient (valid average)
np.mean(preds_all_runs.loc[(preds_all_runs.index == "DKTK12") & (preds_all_runs["cohort"] == "valid"), [pred_col]])
# Out:
# glm_prediction    9.547349
# dtype: float64

# %%
ensemble_train = ensemble_preds.xs("train", level="cohort") #ensemble_preds[ensemble_preds.index.get_level_values(1) == "train"]
ensemble_train
# Out:
#             glm_prediction     LRCtime  LRC
# id
# DKTK12            5.477161   15.802875  1.0
# DKTK14            4.913237    8.344969  0.0
# DKTK15           12.419215    4.895277  1.0
# DKTK17            0.200958   61.075975  0.0
# DKTK19            7.941060    9.757700  1.0
# DKTK20           18.401298    1.347023  1.0
# DKTK21            0.666916    7.655031  0.0
# DKTK22            0.814012   61.470226  0.0
# DKTK23           17.085563    1.379877  1.0
# DKTK24            5.203019    7.720739  0.0
# DKTK25            8.606118    7.655031  1.0
# DKTK26            2.827543   22.833676  0.0
# DKTK29           16.543733    2.299795  1.0
# DKTK30           14.301247    3.876797  1.0
# DKTK31           11.728613    4.895277  1.0
# DKTK33            3.554308   18.529774  0.0
# DKTK36           -4.214331    5.125257  0.0
# DKTK37            6.179989   12.747433  1.0
# DKTK38            3.517826    1.379877  0.0
# DKTK39            9.517853    7.195072  1.0
# DKTK40            7.383675   11.104723  1.0
# DKTK41            0.533836    2.858316  0.0
# DKTK44            1.920216   27.893224  0.0
# DKTK47            7.844586    3.909651  0.0
# DKTK48            0.076407   54.308008  0.0
# DKTK49            4.999567   20.008214  1.0
# DKTK50           -0.845694  127.901437  1.0
# DKTK52            9.066501    1.971253  0.0
# DKTK53            9.607403    6.965092  1.0
# DKTK54            8.872458    7.425051  1.0
# ...                    ...         ...  ...
# DKTK_MUC04        3.663348   33.314168  1.0
# DKTK_TU01        -2.344378   51.383984  0.0
# DKTK_TU02         0.909817   54.932238  0.0
# DKTK_TU03         2.757475    7.687885  0.0
# DKTK_TU04         8.827583    7.852156  1.0
# DKTK_TU05         6.620173    6.833676  0.0
# DKTK_TU06         0.367282   59.104723  0.0
# DKTK_TU07         0.464768   59.827515  0.0
# DKTK_TU08         1.463238   32.821355  0.0
# DKTK_TU09        -1.457920    9.823409  0.0
# DKTK_TU10         0.391309   52.336756  0.0
# DKTK_TU11         0.177848   58.644764  0.0
# DKTK_TU12         1.580198   60.451745  0.0
# DKTK_TU13         2.684568   49.248460  0.0
# DKTK_TU14         1.782817   21.815195  0.0
# DKTK_TU15        -0.140800   67.219713  0.0
# DKTK_TU16         6.109251    4.271047  0.0
# DKTK_TU17         6.419872   11.827515  1.0
# DKTK_TU18         6.308845   12.714579  1.0
# DKTK_TU19         7.341098   11.236140  1.0
# DKTK_TU20         0.351796   40.739220  0.0
# DKTK_TU21        11.697168    4.928131  1.0
# DKTK_TU22        13.317555    4.566735  1.0
# DKTK_TU23         7.747800    9.856263  1.0
# DKTK_TU24         9.550621    6.997947  1.0
# DKTK_TU25         6.148295   11.728953  1.0
# DKTK_TU26         0.492368   34.595483  0.0
# DKTK_TU27        -2.463636   67.121150  0.0
# DKTK_TU28         5.371991   16.492813  1.0
# DKTK_TU29         5.824805   14.028747  1.0
#
# [206 rows x 3 columns]

# %%
ensemble_valid = ensemble_preds.xs("valid", level="cohort") #ensemble_preds[ensemble_preds.index.get_level_values(1) == "valid"]
ensemble_valid
# Out:
#             glm_prediction     LRCtime  LRC
# id
# DKTK12            9.547349   15.802875  1.0
# DKTK14           15.317744    8.344969  0.0
# DKTK15           -3.351909    4.895277  1.0
# DKTK17            5.612844   61.075975  0.0
# DKTK19            5.129105    9.757700  1.0
# DKTK20           -1.461129    1.347023  1.0
# DKTK21            3.302805    7.655031  0.0
# DKTK22            5.315658   61.470226  0.0
# DKTK23            7.260661    1.379877  1.0
# DKTK24            4.352766    7.720739  0.0
# DKTK25            4.210918    7.655031  1.0
# DKTK26            2.052006   22.833676  0.0
# DKTK29           10.974435    2.299795  1.0
# DKTK30            7.313420    3.876797  1.0
# DKTK31           12.156450    4.895277  1.0
# DKTK33            9.198380   18.529774  0.0
# DKTK36           -0.768012    5.125257  0.0
# DKTK37            2.932027   12.747433  1.0
# DKTK38            5.045311    1.379877  0.0
# DKTK39            7.511264    7.195072  1.0
# DKTK40            2.399131   11.104723  1.0
# DKTK41            0.334780    2.858316  0.0
# DKTK44            6.178356   27.893224  0.0
# DKTK47           15.157873    3.909651  0.0
# DKTK48            0.541298   54.308008  0.0
# DKTK49            8.268640   20.008214  1.0
# DKTK50            5.568557  127.901437  1.0
# DKTK52           18.379781    1.971253  0.0
# DKTK53           11.310770    6.965092  1.0
# DKTK54            8.405171    7.425051  1.0
# ...                    ...         ...  ...
# DKTK_MUC04        9.280533   33.314168  1.0
# DKTK_TU01         2.819900   51.383984  0.0
# DKTK_TU02         7.671969   54.932238  0.0
# DKTK_TU03         2.454906    7.687885  0.0
# DKTK_TU04        10.351012    7.852156  1.0
# DKTK_TU05         8.365583    6.833676  0.0
# DKTK_TU06         6.429300   59.104723  0.0
# DKTK_TU07         6.115554   59.827515  0.0
# DKTK_TU08         1.416053   32.821355  0.0
# DKTK_TU09         0.757195    9.823409  0.0
# DKTK_TU10         6.078205   52.336756  0.0
# DKTK_TU11         5.552684   58.644764  0.0
# DKTK_TU12         0.324512   60.451745  0.0
# DKTK_TU13         3.861463   49.248460  0.0
# DKTK_TU14         2.251964   21.815195  0.0
# DKTK_TU15        -0.205064   67.219713  0.0
# DKTK_TU16        -1.949682    4.271047  0.0
# DKTK_TU17         2.470691   11.827515  1.0
# DKTK_TU18         8.950018   12.714579  1.0
# DKTK_TU19         6.416743   11.236140  1.0
# DKTK_TU20         4.982847   40.739220  0.0
# DKTK_TU21         3.916726    4.928131  1.0
# DKTK_TU22         4.384923    4.566735  1.0
# DKTK_TU23         4.209758    9.856263  1.0
# DKTK_TU24         7.076838    6.997947  1.0
# DKTK_TU25         3.157758   11.728953  1.0
# DKTK_TU26         3.597959   34.595483  0.0
# DKTK_TU27         1.820376   67.121150  0.0
# DKTK_TU28         1.802325   16.492813  1.0
# DKTK_TU29         2.115376   14.028747  1.0
#
# [206 rows x 3 columns]

# %%
ensemble_test = ensemble_preds.xs("test", level="cohort")  #ensemble_preds[ensemble_preds.index.get_level_values(1) == "test"]
ensemble_test
# Out:
#          glm_prediction    LRCtime  LRC
# id
# FDG01          1.100602  19.351129  1.0
# FDG03          5.529275   9.889117  0.0
# FDG05         -0.181082  61.634497  0.0
# FDG06          6.133534  62.094456  0.0
# FDG07          5.563163  69.585216  0.0
# FDG09          1.463857   4.172485  1.0
# FDG13          4.099820   4.435318  1.0
# FDG14          7.773242   7.852156  0.0
# FDG15          7.778138  61.963039  0.0
# FDG16          8.998417   1.478439  0.0
# FDG18          2.093179   4.796715  0.0
# FDG19         -2.615608   3.285421  1.0
# FDG20          4.288299  62.882957  0.0
# FDG22          3.679325  22.176591  1.0
# FDG23          7.652524  13.798768  0.0
# FDG24          3.127278  14.587269  0.0
# FDG28          6.386619   3.975359  1.0
# FDG29          5.474519  14.455852  1.0
# FDG38         -2.207520  31.868583  1.0
# FDG42          2.669214  62.193018  0.0
# FMISO01        1.917541  41.396304  0.0
# FMISO02        4.778739  60.648871  0.0
# FMISO03        7.099264   4.698152  1.0
# FMISO04        8.880682   6.735113  1.0
# FMISO05       -2.684156   1.347023  0.0
# FMISO06        3.885403   3.055441  0.0
# FMISO07        4.405421  11.794661  1.0
# FMISO08        4.081001  10.940452  0.0
# FMISO09        6.798259  75.236140  0.0
# FMISO10        0.361060  28.156057  0.0
# ...                 ...        ...  ...
# FMISO39        3.132219   9.034908  1.0
# FMISO40        8.065875  20.468172  0.0
# FMISO41        6.847057  10.447639  1.0
# FMISO43        1.471067  45.075975  0.0
# FMISO44        3.084730  22.899384  0.0
# FMISO45        2.239860  38.406571  0.0
# FMISO46        1.994498  42.546201  0.0
# FMISO48       -0.535987  37.946612  0.0
# FMISO49        4.352871  37.355236  0.0
# FMISO50       12.121060  32.262834  0.0
# FMISO51        2.525846  32.262834  0.0
# FMISO52        6.271104  13.010267  0.0
# FMISO53        5.845135  25.790554  0.0
# FMISO55        7.542984  23.983573  0.0
# FMISO56        5.526987  23.819302  0.0
# FMISO57       -1.737581  18.201232  0.0
# Tue007         8.065171  65.248460  0.0
# Tue009         6.370190  61.470226  0.0
# Tue012         8.989290   8.180698  1.0
# Tue015         4.405066  29.437372  0.0
# Tue016         6.637912  41.133470  0.0
# Tue017         3.033663  28.484600  0.0
# Tue018         4.836692  25.889117  0.0
# Tue019         3.213433  29.470226  0.0
# Tue020       -23.439013  39.293634  0.0
# Tue021         8.100634  37.223819  0.0
# Tue022         4.333259   5.815195  1.0
# Tue023         3.912626   2.234086  0.0
# Tue024         6.585712   5.749487  1.0
# Tue025         6.056575   2.135524  1.0
#
# [85 rows x 3 columns]

# %%
# store the dataframes
output_dir = "/home/MED/starkeseb/tmp/ensemble_autoencoder/LCPHM"
os.makedirs(output_dir, exist_ok=True)

ensemble_train.to_csv(os.path.join(output_dir, "ensemble_train.csv"))
ensemble_valid.to_csv(os.path.join(output_dir, "ensemble_valid.csv"))
ensemble_test.to_csv(os.path.join(output_dir, "ensemble_test.csv"))

# %% [markdown]
# # PCA models

# %%
exp_dir = base_dir
pred_col = "pred_risk_per_pat(mean)"

prediction_dfs = {}
for rep_dir in os.listdir(exp_dir):
    if not rep_dir.startswith("rep"):
        continue
    
    rep_path = os.path.join(exp_dir, rep_dir)
    for fold_dir in os.listdir(rep_path):
        if not fold_dir.startswith("fold"):
            continue
        fold_path = os.path.join(rep_path, fold_dir)
        
        for pca_dir in os.listdir(fold_path):
            if not pca_dir.startswith("predictions_pca_"):
                continue
            pca_path = os.path.join(fold_path, pca_dir)
            n_feats = pca_dir.split("predictions_pca_")[1]

            if n_feats not in prediction_dfs:
                prediction_dfs[n_feats] = []
            
            
            pred = pd.read_csv(os.path.join(pca_path, "predictions.csv"))
            pred = pred[["id", "cohort", pred_col]]
            
            prediction_dfs[n_feats].append(pred)

# %%
prediction_dfs.keys()
# Out:
# dict_keys(['10_comp', '1_comp', '2_comp', '5_comp'])

# %%
ensemble_prediction_dfs = {}
for k, df_list in prediction_dfs.items():
    print(k, len(df_list))
    ensemble_prediction_dfs[k] = pd.concat(df_list)
# Out:
# 10_comp 30
# 1_comp 30
# 2_comp 30
# 5_comp 30

# %%
df_10_comp = ensemble_prediction_dfs["10_comp"]
df_10_comp  # now has 30 entries per patient => 30 * 291 rows
# Out:
#           id      cohort  pred_risk_per_pat(mean)
# 0     DKTK12    training                 0.501181
# 1     DKTK14    training                 0.080416
# 2     DKTK15    training                 0.177172
# 3     DKTK17    training                 0.452803
# 4     DKTK19    training                -0.040930
# 5     DKTK20    training                 0.632301
# 6     DKTK21    training                 0.015730
# 7     DKTK22    training                 0.390161
# 8     DKTK23    training                -0.290966
# 9     DKTK24  validation                 0.192588
# 10    DKTK25    training                 0.500895
# 11    DKTK26    training                -0.226733
# 12    DKTK29    training                 0.204813
# 13    DKTK30    training                 0.110842
# 14    DKTK31    training                 0.623396
# 15    DKTK33    training                 0.833901
# 16    DKTK36    training                -0.809925
# 17    DKTK37  validation                -0.501519
# 18    DKTK38    training                -0.214000
# 19    DKTK39    training                 0.174398
# 20    DKTK40    training                 0.762686
# 21    DKTK41    training                 0.012225
# 22    DKTK44  validation                 0.260239
# 23    DKTK47    training                 0.237789
# 24    DKTK48    training                -0.415511
# 25    DKTK49    training                 0.816611
# 26    DKTK50    training                -0.238958
# 27    DKTK52    training                 0.888960
# 28    DKTK53    training                 1.090996
# 29    DKTK54  validation                 0.175899
# ..       ...         ...                      ...
# 261  FMISO39        test                -0.656440
# 262  FMISO40        test                 0.069150
# 263  FMISO41        test                 0.616912
# 264  FMISO43        test                -0.382519
# 265  FMISO44        test                -0.393910
# 266  FMISO45        test                -0.288423
# 267  FMISO46        test                -0.017022
# 268  FMISO48        test                -0.422183
# 269  FMISO49        test                 0.028607
# 270  FMISO50        test                 0.240918
# 271  FMISO51        test                -0.344377
# 272  FMISO52        test                 0.337666
# 273  FMISO53        test                -0.010086
# 274  FMISO55        test                 0.166394
# 275  FMISO56        test                 0.332909
# 276  FMISO57        test                -1.042743
# 277   Tue007        test                 0.546427
# 278   Tue009        test                 0.330385
# 279   Tue012        test                 0.805438
# 280   Tue015        test                 0.376511
# 281   Tue016        test                -0.131511
# 282   Tue017        test                -0.163795
# 283   Tue018        test                 0.211761
# 284   Tue019        test                 0.271253
# 285   Tue020        test                 0.088507
# 286   Tue021        test                 0.594188
# 287   Tue022        test                -0.048910
# 288   Tue023        test                -0.766125
# 289   Tue024        test                 0.029423
# 290   Tue025        test                -0.250122
#
# [8730 rows x 3 columns]

# %%
df_10_comp[(df_10_comp.id == "DKTK12") & (df_10_comp.cohort == "validation")].mean()
# Out:
# pred_risk_per_pat(mean)    0.335356
# dtype: float64

# %%
df_10_comp[(df_10_comp.id == "Tue025") & (df_10_comp.cohort == "test")].mean()
# Out:
# pred_risk_per_pat(mean)   -0.252864
# dtype: float64

# %%
df_10_comp.groupby(["id", "cohort"]).mean()
# Out:
#                     pred_risk_per_pat(mean)
# id      cohort
# DKTK12  training                   0.349990
#         validation                 0.335356
# DKTK14  training                   0.119022
#         validation                 0.223997
# DKTK15  training                   0.017987
#         validation                 0.111670
# DKTK17  training                   0.382696
#         validation                 0.576832
# DKTK19  training                  -0.189788
#         validation                -0.084487
# DKTK20  training                   0.596625
#         validation                 0.269010
# DKTK21  training                   0.088813
#         validation                 0.130505
# DKTK22  training                   0.396852
#         validation                 0.377468
# DKTK23  training                  -0.159397
#         validation                -0.290621
# DKTK24  training                   0.036166
#         validation                 0.065536
# DKTK25  training                   0.589985
#         validation                 0.474523
# DKTK26  training                  -0.126244
#         validation                -0.128934
# DKTK29  training                   0.114763
#         validation                 0.145862
# DKTK30  training                   0.322921
#         validation                 0.368213
# DKTK31  training                   0.610085
#         validation                 0.394045
# ...                                     ...
# FMISO39 test                      -0.602377
# FMISO40 test                       0.051087
# FMISO41 test                       0.504985
# FMISO43 test                      -0.388290
# FMISO44 test                      -0.402925
# FMISO45 test                      -0.303395
# FMISO46 test                      -0.029234
# FMISO48 test                      -0.465211
# FMISO49 test                      -0.032990
# FMISO50 test                       0.163065
# FMISO51 test                      -0.386336
# FMISO52 test                       0.316765
# FMISO53 test                      -0.171933
# FMISO55 test                       0.021262
# FMISO56 test                       0.212079
# FMISO57 test                      -1.056047
# Tue007  test                       0.612276
# Tue009  test                       0.259720
# Tue012  test                       0.880372
# Tue015  test                       0.207888
# Tue016  test                      -0.216710
# Tue017  test                      -0.333199
# Tue018  test                       0.020971
# Tue019  test                       0.347273
# Tue020  test                      -0.140140
# Tue021  test                       0.543345
# Tue022  test                      -0.020532
# Tue023  test                      -0.611953
# Tue024  test                       0.042391
# Tue025  test                      -0.252864
#
# [497 rows x 1 columns]

# %%
ensemble_predictions_grouped = {}
for k, df in ensemble_prediction_dfs.items():
    tmp = df.groupby(["id", "cohort"]).mean()
    # also join the outcome
    tmp = tmp.join(outcome, on="id")
    ensemble_predictions_grouped[k] = tmp

# %%
foo = ensemble_predictions_grouped["10_comp"] # 206 * 2 + 85 rows 
foo
# Out:
#                     pred_risk_per_pat(mean)    LRCtime  LRC
# id      cohort
# DKTK12  training                   0.349990  15.802875  1.0
#         validation                 0.335356  15.802875  1.0
# DKTK14  training                   0.119022   8.344969  0.0
#         validation                 0.223997   8.344969  0.0
# DKTK15  training                   0.017987   4.895277  1.0
#         validation                 0.111670   4.895277  1.0
# DKTK17  training                   0.382696  61.075975  0.0
#         validation                 0.576832  61.075975  0.0
# DKTK19  training                  -0.189788   9.757700  1.0
#         validation                -0.084487   9.757700  1.0
# DKTK20  training                   0.596625   1.347023  1.0
#         validation                 0.269010   1.347023  1.0
# DKTK21  training                   0.088813   7.655031  0.0
#         validation                 0.130505   7.655031  0.0
# DKTK22  training                   0.396852  61.470226  0.0
#         validation                 0.377468  61.470226  0.0
# DKTK23  training                  -0.159397   1.379877  1.0
#         validation                -0.290621   1.379877  1.0
# DKTK24  training                   0.036166   7.720739  0.0
#         validation                 0.065536   7.720739  0.0
# DKTK25  training                   0.589985   7.655031  1.0
#         validation                 0.474523   7.655031  1.0
# DKTK26  training                  -0.126244  22.833676  0.0
#         validation                -0.128934  22.833676  0.0
# DKTK29  training                   0.114763   2.299795  1.0
#         validation                 0.145862   2.299795  1.0
# DKTK30  training                   0.322921   3.876797  1.0
#         validation                 0.368213   3.876797  1.0
# DKTK31  training                   0.610085   4.895277  1.0
#         validation                 0.394045   4.895277  1.0
# ...                                     ...        ...  ...
# FMISO39 test                      -0.602377   9.034908  1.0
# FMISO40 test                       0.051087  20.468172  0.0
# FMISO41 test                       0.504985  10.447639  1.0
# FMISO43 test                      -0.388290  45.075975  0.0
# FMISO44 test                      -0.402925  22.899384  0.0
# FMISO45 test                      -0.303395  38.406571  0.0
# FMISO46 test                      -0.029234  42.546201  0.0
# FMISO48 test                      -0.465211  37.946612  0.0
# FMISO49 test                      -0.032990  37.355236  0.0
# FMISO50 test                       0.163065  32.262834  0.0
# FMISO51 test                      -0.386336  32.262834  0.0
# FMISO52 test                       0.316765  13.010267  0.0
# FMISO53 test                      -0.171933  25.790554  0.0
# FMISO55 test                       0.021262  23.983573  0.0
# FMISO56 test                       0.212079  23.819302  0.0
# FMISO57 test                      -1.056047  18.201232  0.0
# Tue007  test                       0.612276  65.248460  0.0
# Tue009  test                       0.259720  61.470226  0.0
# Tue012  test                       0.880372   8.180698  1.0
# Tue015  test                       0.207888  29.437372  0.0
# Tue016  test                      -0.216710  41.133470  0.0
# Tue017  test                      -0.333199  28.484600  0.0
# Tue018  test                       0.020971  25.889117  0.0
# Tue019  test                       0.347273  29.470226  0.0
# Tue020  test                      -0.140140  39.293634  0.0
# Tue021  test                       0.543345  37.223819  0.0
# Tue022  test                      -0.020532   5.815195  1.0
# Tue023  test                      -0.611953   2.234086  0.0
# Tue024  test                       0.042391   5.749487  1.0
# Tue025  test                      -0.252864   2.135524  1.0
#
# [497 rows x 3 columns]

# %%
foo.xs("test", level="cohort")
# Out:
#          pred_risk_per_pat(mean)    LRCtime  LRC
# id
# FDG01                  -0.077978  19.351129  1.0
# FDG03                   0.088886   9.889117  0.0
# FDG05                  -0.541083  61.634497  0.0
# FDG06                   0.042504  62.094456  0.0
# FDG07                   0.621074  69.585216  0.0
# FDG09                   0.105067   4.172485  1.0
# FDG13                   0.018393   4.435318  1.0
# FDG14                  -0.651950   7.852156  0.0
# FDG15                   0.296900  61.963039  0.0
# FDG16                   0.136057   1.478439  0.0
# FDG18                  -0.513513   4.796715  0.0
# FDG19                  -0.154652   3.285421  1.0
# FDG20                   0.208391  62.882957  0.0
# FDG22                   0.060251  22.176591  1.0
# FDG23                   0.394856  13.798768  0.0
# FDG24                  -0.052701  14.587269  0.0
# FDG28                   0.445713   3.975359  1.0
# FDG29                   0.460150  14.455852  1.0
# FDG38                  -0.172783  31.868583  1.0
# FDG42                  -0.854268  62.193018  0.0
# FMISO01                 0.302072  41.396304  0.0
# FMISO02                -0.107922  60.648871  0.0
# FMISO03                -0.030208   4.698152  1.0
# FMISO04                 0.778994   6.735113  1.0
# FMISO05                -0.968973   1.347023  0.0
# FMISO06                 0.125829   3.055441  0.0
# FMISO07                 0.035938  11.794661  1.0
# FMISO08                 0.465065  10.940452  0.0
# FMISO09                -0.012009  75.236140  0.0
# FMISO10                -0.230205  28.156057  0.0
# ...                          ...        ...  ...
# FMISO39                -0.602377   9.034908  1.0
# FMISO40                 0.051087  20.468172  0.0
# FMISO41                 0.504985  10.447639  1.0
# FMISO43                -0.388290  45.075975  0.0
# FMISO44                -0.402925  22.899384  0.0
# FMISO45                -0.303395  38.406571  0.0
# FMISO46                -0.029234  42.546201  0.0
# FMISO48                -0.465211  37.946612  0.0
# FMISO49                -0.032990  37.355236  0.0
# FMISO50                 0.163065  32.262834  0.0
# FMISO51                -0.386336  32.262834  0.0
# FMISO52                 0.316765  13.010267  0.0
# FMISO53                -0.171933  25.790554  0.0
# FMISO55                 0.021262  23.983573  0.0
# FMISO56                 0.212079  23.819302  0.0
# FMISO57                -1.056047  18.201232  0.0
# Tue007                  0.612276  65.248460  0.0
# Tue009                  0.259720  61.470226  0.0
# Tue012                  0.880372   8.180698  1.0
# Tue015                  0.207888  29.437372  0.0
# Tue016                 -0.216710  41.133470  0.0
# Tue017                 -0.333199  28.484600  0.0
# Tue018                  0.020971  25.889117  0.0
# Tue019                  0.347273  29.470226  0.0
# Tue020                 -0.140140  39.293634  0.0
# Tue021                  0.543345  37.223819  0.0
# Tue022                 -0.020532   5.815195  1.0
# Tue023                 -0.611953   2.234086  0.0
# Tue024                  0.042391   5.749487  1.0
# Tue025                 -0.252864   2.135524  1.0
#
# [85 rows x 3 columns]

# %%
output_dir = "/home/MED/starkeseb/tmp/ensemble_autoencoder/"


for k, df in ensemble_predictions_grouped.items():
    output_base = os.path.join(output_dir, "PCA_" + k)
    os.makedirs(output_base, exist_ok=True)
    
    # make train valid test
    ensemble_train = df.xs("training", level="cohort")
    ensemble_valid = df.xs("validation", level="cohort")
    ensemble_test = df.xs("test", level="cohort")
    
    ensemble_train.to_csv(os.path.join(output_base, "ensemble_train.csv"))
    ensemble_valid.to_csv(os.path.join(output_base, "ensemble_valid.csv"))
    ensemble_test.to_csv(os.path.join(output_base, "ensemble_test.csv"))
